# %%
練習時間
請寫一個函式用來計算 Mean Square Error
𝑀𝑆𝐸=1𝑛∑𝑛𝑖=1(𝑌𝑖−𝑌̂ 𝑖)2 
Hint: 如何取平方
[作業目標]
仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)
[作業重點]
注意程式的縮排
是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])
# Out:
#   File "<ipython-input-8-b77a86ea47cc>", line 2
#     請寫一個函式用來計算 Mean Square Error
#                   ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101)*5)*w+b
plt.plot(x_lin, y, 'b.', label = 'data point')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin* w + b
plt.plot(x_lin, y, "g.", label = "result")
plt.plot(x_lin, y_hat, "r-", label = "prediction")
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
def mean_absolute_error(y,yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.4f" %(MAE) )
# Out:
# The Mean absolute error is 11.3944

# %%
def mean_squared_error(y,yp):
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 193.649

# %%
[作業2]
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
1.	你選的這組資料為何重要
資料中收集了芝加哥的犯罪的犯罪資料，裡面記載了許多年的犯罪資料。其中可能有著可以分析的犯罪熱點以及時間等等的資訊
2.	資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
資料來源: Chicago Police Department's CLEAR
蒐集方式:警局本身的收案資料
3.	蒐集而來的資料型態為何
BigQuery Dataset
類似Excel的資料表形式
4.	這組資料想解決的問題如何評估
可以分析不同的犯罪類型和攻擊事件發生率等等的預防性資料分析。
[作業3]
像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1.	核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
以一個自由載客車隊的來說，增加載客率是提升業績的最好辦法。假設載客率是能夠提升的空間。
2.	資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
資料需要收集例如上下車地點、時間、顧客人數、等候時間、天氣和車隊空車數等等。資料收集來源司機或者利用車隊建立的電子系統收集。這些資料能提供載客資訊以及車隊本身的運作程度。
3.	蒐集而來的資料型態為何
文字與數字的紀錄形式。
4.	你要回答的問題，其如何評估 (tips：你的假設如何驗證)
在分析後需找出不足之處，例如某些時間段司機過少、載客區域的位置熱點和天氣影響等等。才能進行改進以及假設的驗證。例如某個時間段某區域的司機過少，需增加短時間的車輛進行載運。或者因為氣候不佳導致塞車需有額外的路線規劃，減少行車時間。以載客數量的提升當作驗證的證據。
# Out:
#   File "<ipython-input-14-17a3cdd5c5a8>", line 2
#     請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#             ^
# SyntaxError: invalid syntax
